# %%
import node_classification as nc

# %%
# %matplotlib inline

# %%
G = nc.TestNetwork(42)

# %%
cats = nc.node_categories(G, denseThres=5)

# %%
cats
# Out:
# {0: 'root',
#  1: 'inner tree node',
#  2: 'root',
#  3: 'bulk',
#  4: 'bulk',
#  5: 'root',
#  6: 'inner tree node',
#  7: 'dense sprout',
#  8: 'inner tree node',
#  9: 'inner tree node',
#  10: 'inner tree node',
#  11: 'inner tree node',
#  12: 'proper leaf',
#  13: 'dense sprout',
#  14: 'inner tree node',
#  15: 'dense sprout',
#  16: 'proper leaf',
#  17: 'dense sprout',
#  18: 'bulk',
#  19: 'bulk',
#  20: 'dense sprout',
#  21: 'proper leaf',
#  22: 'dense sprout',
#  23: 'dense sprout',
#  24: 'dense sprout',
#  25: 'inner tree node',
#  26: 'root',
#  27: 'dense sprout',
#  28: 'sparse sprout',
#  29: 'proper leaf',
#  30: 'proper leaf',
#  31: 'inner tree node',
#  32: 'dense sprout',
#  33: 'dense sprout',
#  34: 'proper leaf',
#  35: 'proper leaf',
#  36: 'proper leaf',
#  37: 'proper leaf',
#  38: 'proper leaf',
#  39: 'dense sprout',
#  40: 'bulk',
#  41: 'bulk'}

# %%
nc.plot_network(G, cats)
# Out:
# (<Figure size 842.4x595.44 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fd399217150>)
